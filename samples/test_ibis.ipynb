# %%
from pytaq.cleaning.trades import clean_trades
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pytaq.cleaning.trades import clean_trades
#
# ModuleNotFoundError: No module named 'pytaq'
